# %%
#a
a = 2
b = 3
c = 5
print((a+b)/c)
# Out:
# 1.0

# %%
#b
a = 19
b = 3
c = 5
d = 1
print((a-b)/(c-d))
# Out:
# 4.0

# %%
#c
a = 36
b = 2
c = 3
print(a/(b*c))
# Out:
# 6.0

# %%
#d
a = 48
b = 12
c = 12/3
print((a+b)/c)
# Out:
# 15.0

# %%
hatvanyalap = 5
hatvany = 4
print(hatvanyalap ** hatvany)
# Out:
# 625

# %%
hatvanyalap = 64
hatvany = (1/3)
print(round(hatvanyalap ** hatvany))
# Out:
# 4

# %%
#f
gyokkitevo = (1/2)
hatvanyertek = 121
print(hatvanyertek ** gyokkitevo)
# Out:
# 11.0

# %%
#h
gyokkitevo = (1/3)
hatvanyertek = 27
print(hatvanyertek ** gyokkitevo)
# Out:
# 3.0

# %%
#i
a = 5
b = 6
c = 2
d = 4
e = 1
print(a*b*(c/(d*a))-e)
# Out:
# 2.0

# %%
#j
a = 2
b = 3 
c = 4
d = 5
print((a+b-c*d)/(-a-b))
# Out:
# 3.0

# %%
#k 
gyokkitevo = (1/2)
a = 4
b = 5
hatvanyertek = a * b - a 
print(hatvanyertek ** gyokkitevo)
# Out:
# 4.0

# %%
#l 
gyokkitevo = (1/3)
a = 5
b = 8
c = 3
d = 4
e = 1
hatvanyertek = a * b - c * d - e
print(hatvanyertek ** gyokkitevo)
# Out:
# 3.0

# %%
#m
gyokkitevo = (1/2)
hatvanyertek = 2 * 2 + 2 * 4 * 4
print(hatvanyertek ** gyokkitevo)
# Out:
# 6.0

# %%
#n 
hatvanyertek = (1/2)
gyokkitevo = 5 * 5 - (4 * 4)
print(hatvanyertek ** gyokkitevo)
# Out:
# 0.001953125

# %%
#n 
hatvanyertek = (1/2)
gyokkitevo = 5 * 5 - 4 * 4
print(gyokkitevo)
# Out:
# 9

# %%
import math


a = 5**2
b = 4**2
n = math.sqrt(a - b)
print(n)
# Out:
# 3.0

# %%
a = 2**3
b = 3**2
o = (a + b - 1)**(1/4)
print(o)
# Out:
# 2.0

# %%
a = 10**3
b = 2**3 * 3
p = (a + b)**(1/10)
print(p)
# Out:
# 2.0

# %%
a = 2**10
b = 2**4
c = 3**2
q = (a - b - c + 1)**(1/3)
print(round(q))
# Out:
# 10

# %%
a = 5**2
b = 2**4
felso = -5 + math.sqrt(a - b)
also = 2 * 5
r = felso / also
print(r)
# Out:
# -0.2

# %%
a = 3**2
b = 4 * (-3) * 6
felso = -3 - math.sqrt(a - b)
also = 2 * (-3)
s = felso / also
print(s)
# Out:
# 2.0

# %%
a = 16 - 2
b = math.sqrt(a)
A = math.exp(b)
print(A)
# Out:
# 42.16782066919796

# %%
a = 215
b = 3**2
B = math.log(a - b)
print(B)
# Out:
# 5.327876168789581

# %%
angle = math.radians(258)
C = math.sin(angle)
print(C)
# Out:
# -0.9781476007338056

# %%
D = 2873 % 13
print(D)
# Out:
# 0

# %%
a = math.factorial(15)
E = math.cos(a)
print(E)
# Out:
# 0.12657440085283123

# %%
a = 2**8
tan_value = math.tan(math.radians(a))
F = abs(tan_value)
print(F)
# Out:
# 4.010780933535844
